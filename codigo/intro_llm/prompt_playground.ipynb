# %% [markdown]
# <a href="https://colab.research.google.com/github/sonder-art/automl_o23/blob/main/codigo/intro_llm/prompt_playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cuarto Chino

# %% [markdown]
# La historia del cuarto chino

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Explica el argumento del cuarto chino en inteligencia artificial

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Explica el argumento del cuarto chino en un parrafo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Principios del Prompting

# %% [markdown]
# ## Instruciones claras y especificas

# %% [markdown]
# ### Usar delimitadores

# %% [markdown]
# Resume en 1 parrafo el siguiente texto:
#
# "
# Entiende el modelo: Antes de comenzar, es importante tener una comprensión básica del modelo de lenguaje con el que estás interactuando. ¿Qué tipo de tareas puede realizar? ¿Cuáles son sus limitaciones? Saber qué esperar te ayudará a formular el prompting adecuado.
#
# Especifica el contexto: Al iniciar la conversación con ChatGPT, proporciona un contexto claro para que el modelo sepa sobre qué tema o situación está conversando. Esto puede ser tan simple como una oración introductoria que describa el tema o una pregunta inicial.
#
# Formula preguntas directas: Si deseas respuestas específicas, formula preguntas directas y específicas. Cuanto más claro sea tu interrogante, más probable será que obtengas una respuesta precisa.
#
# Utiliza instrucciones claras: Si deseas que ChatGPT realice una tarea particular, proporciona instrucciones claras y específicas. Por ejemplo, si deseas que resuma un texto, puedes decir: "Por favor, resume el siguiente párrafo en dos oraciones".
#
# Controla la salida con temperaturas: La "temperatura" controla la aleatoriedad en las respuestas del modelo. Un valor bajo (por ejemplo, 0.2) producirá respuestas más determinísticas y conservadoras, mientras que un valor alto (por ejemplo, 0.8) generará respuestas más diversas y creativas.
#
# Limita la longitud de la respuesta: Si deseas respuestas más concisas, puedes establecer un límite de tokens para controlar la longitud de la salida.
#
# Experimenta y ajusta: No te limites a un solo prompt. Experimenta con diferentes enfoques, preguntas y estilos para ver qué tipo de resultados obtienes. Ajusta tus instrucciones según sea necesario para mejorar la calidad de las respuestas.
#
# Revisa y edita: Las respuestas generadas por ChatGPT pueden no ser siempre perfectas. Siempre es una buena práctica revisar y editar las respuestas según tus necesidades o para mejorar la coherencia y precisión.
#
# Mantén la seguridad en mente: Aunque ChatGPT es útil, recuerda que es solo un modelo de lenguaje y puede producir información incorrecta o sesgada. No utilices el modelo para difundir información engañosa o dañina.
#
# Respeto y ética: Utiliza el modelo de manera respetuosa y ética. Evita solicitar contenido inapropiado o insensible, y recuerda que el modelo debe ser tratado como una herramienta que pueda brindar asistencia útil y constructiva.
#
# Siguiendo estos consejos, podrás aprovechar al máximo tu interacción con ChatGPT y obtener resultados más relevantes y precisos. ¡Diviértete experimentando y aprendiendo!
# "

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pide respuestas estructuradas

# %% [markdown]
# Generate a list of three made-up book titles along \
# with their authors and genres.
# Provide them in JSON format with the following keys:
# book_id, title, author, genre.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Especifica condiciones

# %% [markdown]
# User
# Se te proporcionará un texto delimitado por triple comillas. Si contiene una secuencia de instrucciones, reescribe esas instrucciones en el siguiente formato:
#
# Paso 1 - ...
# Paso 2 - …
# …
# Paso N - …
#
# Si el texto no contiene una secuencia de instrucciones, simplemente escribe "No se proporcionaron pasos".
#
# """ Preparar una taza de té es fácil. Primero, necesitas hervir un poco de agua. Mientras eso sucede, agarra una taza y pon una bolsita de té en ella. Una vez que el agua esté suficientemente caliente, simplemente viértela sobre la bolsita de té. Deja que repose un poco para que el té se infunda. Después de unos minutos, saca la bolsita de té. Si lo deseas, puedes agregar azúcar o leche al gusto. ¡Y eso es todo! Ahora tienes una deliciosa taza de té para disfrutar."""

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Se te proporcionará un texto delimitado por triple comillas. Si contiene una secuencia de instrucciones, reescribe esas instrucciones en el siguiente formato:
#
# Paso 1 - ...
# Paso 2 - …
# …
# Paso N - …
#
# Si el texto no contiene una secuencia de instrucciones, simplemente escribe "No se proporcionaron pasos".
#
# """ Me gusta mucho ir a la playa."""

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Few-shot Learning

# %% [markdown]
# Tu tarea es responder de manera coherente.
#
# <niño>: Enséñame sobre la paciencia.
#
# <abuelo>: El río que talla el valle más profundo fluye desde un modesto manantial; la sinfonía más grandiosa se origina de una sola nota; el tapiz más intrincado comienza con un hilo solitario.
#
# <niño>: Enséñame sobre la perseverancia.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Dale tiempo (computo) al modelo para pensar

# %% [markdown]
# ### Especifica detalladamente los pasos a seguir

# %% [markdown]
# Realiza las siguientes acciones:
# 1 - Resumir el siguiente texto delimitado por triple comillas invertidas con una oración.
# 2 - Traducir el resumen al francés.
# 3 - Enumerar cada nombre en el resumen en francés.
# 4 - Generar un objeto JSON que contenga las siguientes claves: french_summary, num_names.
#
# Separa tus respuestas con saltos de línea.
#
# Texto:
# """ En un encantador pueblo, los hermanos Jack y Jill se embarcaron en una búsqueda para traer agua de un pozo en la cima de una colina. Mientras subían, cantando alegremente, la desgracia los golpeó: Jack tropezó con una piedra y rodó colina abajo, con Jill siguiéndolo. Aunque un poco magullados, regresaron a casa recibiendo abrazos reconfortantes. A pesar del percance, sus espíritus aventureros permanecieron inquebrantables y continuaron explorando con alegría.
# """

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# User
# Tu tarea es realizar las siguientes acciones:
# 1 - Resumir el siguiente texto delimitado por <> con una oración.
# 2 - Traducir el resumen al francés.
# 3 - Enumerar cada nombre en el resumen en francés.
# 4 - Generar un objeto JSON que contenga las siguientes claves: french_summary, num_names.
#
# Utiliza el siguiente formato:
# Texto: <texto para resumir>
# Resumen: <resumen>
# Traducción: <traducción del resumen>
# Nombres: <lista de nombres en el resumen en francés>
# JSON de salida: <JSON con el resumen y num_names>
#
# Texto:
# ``` En un encantador pueblo, los hermanos Jack y Jill se embarcaron en una búsqueda para traer agua de un pozo en la cima de una colina. Mientras subían, cantando alegremente, la desgracia los golpeó: Jack tropezó con una piedra y rodó colina abajo, con Jill siguiéndolo. Aunque un poco magullados, regresaron a casa recibiendo abrazos reconfortantes. A pesar del percance, sus espíritus aventureros permanecieron inquebrantables y continuaron explorando con alegría.```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Indica al modelo que piense en la solucion

# %% [markdown]
# Determina si la solución del estudiante es correcta o no.
#
# Pregunta:
# Estoy construyendo una instalación de energía solar y necesito ayuda para calcular los aspectos financieros.
#
# El costo del terreno es de \$100 por pie cuadrado.
# Puedo comprar paneles solares por \$250 por pie cuadrado.
# Negocié un contrato de mantenimiento que me costará \$100,000 fijos por año y $10 por pie cuadrado adicionalmente.
# ¿Cuál es el costo total para el primer año de operaciones como función del número de pies cuadrados?
#
# Solución del estudiante:
# Sea x el tamaño de la instalación en pies cuadrados.
# Costos:
#
# Costo del terreno: 100x
# Costo de paneles solares: 250x
# Costo de mantenimiento: 100,000 + 100x
# Costo total: 100x + 250x + 100,000 + 100x = 450x + 100,000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Tu tarea es determinar si la solución del estudiante es correcta o no.
# Para resolver el problema, sigue estos pasos:
#
# -Primero, resuelve el problema tú mismo.
# -Luego, compara tu solución con la solución del estudiante y evalúa si la solución del estudiante es correcta o no.
# No decidas si la solución del estudiante es correcta hasta que hayas realizado el problema tú mismo.
#
# Usa el siguiente formato:
# Pregunta:
# "
# aquí va la pregunta
# "
# Solución del estudiante:
# "
# aquí va la solución del estudiante
# "
# Solución real
# "
# pasos para resolver el problema y tu solución aquí
# "
# ¿Es la solución del estudiante la misma que la solución real recién calculada?
# "
# sí o no
# "
# Calificación del estudiante:
# "
# correcto o incorrecto
# "
# Pregunta:
# "
# Estoy construyendo una instalación de energía solar y necesito ayuda para calcular los aspectos financieros.
# - El costo del terreno es de \$100 por pie cuadrado.
# - Puedo comprar paneles solares por \$250 por pie cuadrado.
# - Negocié un contrato de mantenimiento que me costará \$100,000 fijos por año, y $10 por pie cuadrado adicionalmente.
# ¿Cuál es el costo total para el primer año de operaciones como función del número de pies cuadrados?
# "
# Solución del estudiante:
# "
# Sea x el tamaño de la instalación en pies cuadrados.
# Costos:
# 1 Costo del terreno: 100x
# 2 Costo de paneles solares: 250x
# 3 Costo de mantenimiento: 100,000 + 100x
# Costo total: 100x + 250x + 100,000 + 100x = 450x + 100,000
# "

# %% [markdown]
# ![image.png](data:image/png;base64,...)
